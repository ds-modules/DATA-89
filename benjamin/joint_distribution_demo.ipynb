# %% [markdown]
# # Joint distribution table → surface visualizer
#
# Independent Beta marginals on $[0,1]^2$: adjust $\Delta$, Beta parameters, vertical axis (probability vs. probability/area), and a rectangle $[a,b]\times[c,d]$ (values snap to multiples of $\Delta$).

# %%
from utils_joint_distribution import run_joint_distribution_demo

run_joint_distribution_demo()
