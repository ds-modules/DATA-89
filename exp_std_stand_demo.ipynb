# %%
# %matplotlib inline
from utils_exp_std_stand_demo import show_exp_std_stand_demo

# Defaults: full distribution menu and all reveal buttons.
# Example alternatives:
# show_exp_std_stand_demo(textbook=True)
# show_exp_std_stand_demo(centrality_only=True)
show_exp_std_stand_demo()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Distribution:', layout=Layout(width='240px'), options=('un…

# %%
show_exp_std_stand_demo(centrality_only=True)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Distribution:', layout=Layout(width='240px'), options=('un…
