# %%
from utils_dartboard import run_dartboard_explorer

# %%
# Display the interactive dartboard visualization
run_dartboard_explorer(R=1.0)
