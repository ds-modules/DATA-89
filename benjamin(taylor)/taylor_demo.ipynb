# %% [markdown]
# # Taylor Series Visualizer
#
# Interactive demo for Taylor approximations up to 4th order.

# %%
from utils_taylor import run_taylor_demo

# Run `viz = launch_taylor_demo()` in a separate cell when you want to display the widget.
def launch_taylor_demo():
    return run_taylor_demo()
