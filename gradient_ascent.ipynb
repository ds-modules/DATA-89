# %%
from utils_ga import show_gradient_ascent

# %%
# Display the interactive gradient ascent visualization (animation version)
show_gradient_ascent(mode='animation')

# %%
# Display the interactive gradient ascent visualization (animation version)
show_gradient_ascent(mode='slider')

# %%
#testing
