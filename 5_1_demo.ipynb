# %%
from utils_dist_5_1 import run_distribution_explorer_51

# %%
# §5.1 Tails and Rare Events — alternate distribution plotter
# Adds: Student-t (continuous), Power law (discrete), and log-scale toggles for x and y axes.
# X-axis log scale is only available when the random variable is nonnegative.
run_distribution_explorer_51()

# %%
run_distribution_explorer_51(dist_type="Power law", lock_distribution=True)
