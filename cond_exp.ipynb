# %% [markdown]
# ## Joint density and conditional expectation
#
# Bivariate normal $(X,Y)$ with zero means, unit variances, and correlation $\rho$. The left panel shows the joint density (heatmap and contours), the regression curve $E[Y\mid X=x]=\rho x$, and the slice at the selected $x$. The right panel shows the conditional density $f_{Y\mid X}(y\mid x)$ with a horizontal line at $E[Y\mid X=x]$.

# %%
from utils_cond_exp import show_conditional_expectation

show_conditional_expectation()
