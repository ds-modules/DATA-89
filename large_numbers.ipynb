# %%
from utils_large_numbers import run_large_numbers_explorer

# %%
# Law of Large Numbers: pick a distribution, click Sample to draw up to 1,000 samples.
# Left: running average vs sample number; right: running histogram and true distribution.
# Adjust the window slider to see when the running average falls inside/outside the band (green/red).
run_large_numbers_explorer()
