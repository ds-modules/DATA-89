# %% [markdown]
# ## Convolution of independent random variables
#
# Choose continuous distributions for $X$ and $Y$, set parameters, and move the sum $s$. The main axes show $f_X$, $f_Y$ (same $x$-axis), and the kernel $f_Y(s-x)$. The right panel shows the joint density $f_X(x)f_Y(y)$ with the line $y=s-x$. The lower-left panel shows the convolution density $f_{X+Y}$ (numerical) when revealed, and points $(s,f_{X+Y}(s))$.

# %%
# %matplotlib inline
from utils_convolution import show_convolution

show_convolution()
