# %% [markdown]
# # Week 4: Composite Functions (3D)
#
# Explore composition \(f_{\mathrm{out}}(f_{\mathrm{in}}(x))\) in 3D:
#
# - **Axes**: horizontal = \(x\) (input to \(f_{\mathrm{in}}\)), out of screen = \(f_{\mathrm{in}}(x)\), vertical = \(f_{\mathrm{out}}(f_{\mathrm{in}}(x))\).
# - **Inner function**: choose any type; **outer function**: restricted to nonnegative types (e.g. Power, Root, Exponential, Bump).
# - Use **Show inner** to plot the inner function in the floor plane; **Show outer** to plot the outer function and the surface \(z = f_{\mathrm{out}}(y)\); **Compose Functions** to reveal the 3D composite curve and its projection on the \(x\)–\(z\) plane.
# - **Move Cursor** slider moves the input \(x\); scatter points and dashed lines show \((x, f_{\mathrm{in}}(x), 0)\), \((x, f_{\mathrm{in}}(x), f_{\mathrm{out}}(f_{\mathrm{in}}(x)))\), and \((x, 0, f_{\mathrm{out}}(f_{\mathrm{in}}(x)))\).
# - **Reset all** hides all plots.

# %%
from utils_week_4 import show_composite_3d

composition_3d = show_composite_3d()
