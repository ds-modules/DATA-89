# %% [markdown]
# # Week 3: Basic Function Properties

# %%
from utils_week3_functions import (
    show_function_properties,
    show_function_inverse,
    show_function_combination,
    show_function_composition
)

# %% [markdown]
# ---
# ## Demo 1: Function Properties Quiz
#
# Select a standard function type, adjust its parameters and transformations, then test your understanding:
# - Use the **Properties Quiz** checkboxes to guess which properties apply
# - Properties: symmetric (even), monotonic, convex, concave, nonnegative
# - Click **Check Answers** to see how you did

# %%
properties = show_function_properties()

# %% [markdown]
# ---
# ## Demo 2: Function Inverse
#
# Explore inverse functions (restricted to monotonic functions only):
# - The $y = x$ line shows the reflection axis
# - Move the **Cursor** slider along the function
# - The **reflection square** shows how $(x, f(x))$ maps to $(f(x), x)$:
#   - Corners: $(x, f(x))$, $(x, x)$, $(f(x), f(x))$, $(f(x), x)$
# - Toggle **Show Inverse** to display/hide the inverse curve

# %%
inverse = show_function_inverse()

# %% [markdown]
# ---
# ## Demo 3: Function Combination
#
# Combine two functions $f(x)$ and $g(x)$ using:
# - **Linear Combination**: $h(x) = w_f \cdot f(x) + w_g \cdot g(x)$
#   - View as separate functions or stacked
# - **Multiply**: $h(x) = f(x) \cdot g(x)$
#   - See the factors panel with dashed multiples and the product panel

# %%
combination = show_function_combination()

# %% [markdown]
# ---
# ## Demo 4: Function Composition
#
# Build composite functions step-by-step:
# 1. Select inner and outer functions with their parameters
# 2. Click **Compose Functions** to enter composition mode
# 3. Adjust the x slider to see the step-by-step construction:
#    - Start at $(x, 0)$
#    - Go up to $(x, f_{\text{inner}}(x))$
#    - Move horizontally to $(f_{\text{inner}}(x), f_{\text{inner}}(x))$ on the $y=x$ line
#    - Go up/down to $(f_{\text{inner}}(x), f_{\text{outer}}(f_{\text{inner}}(x)))$
#    - Move horizontally to the final point $(x, f_{\text{outer}}(f_{\text{inner}}(x)))$
# 4. Click **Save Point** to add the final point to your collection
# 5. Click **Reveal Composite** to show the full composite curve

# %%
composition = show_function_composition()
